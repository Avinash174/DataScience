# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
plt.pie(x=df['class'].value_counts(),labels=df['class'].value_counts().index,autopct='%.2f%%')
plt.show()

# %%
df['class'].value_counts(normalize=True) * 100 # claculate percentage of value count
# Out:
# class
# Third     55.106622
# First     24.242424
# Second    20.650954
# Name: proportion, dtype: float64

# %%
df['sex'].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['sex'].value_counts(normalize=True)*100
# Out:
# sex
# male      64.758698
# female    35.241302
# Name: proportion, dtype: float64

# %%
df['who'].value_counts()
# Out:
# who
# man      537
# woman    271
# child     83
# Name: count, dtype: int64

# %%
df['who'].value_counts(normalize=True)*100
# Out:
# who
# man      60.269360
# woman    30.415264
# child     9.315376
# Name: proportion, dtype: float64

# %%
plt.pie(x=df['who'].value_counts(),labels=df['who'].value_counts().index,)
plt.show()

# %%
expload=[0,0,0.1]
plt.pie(x=df['class'].value_counts(),labels=df['class'].value_counts().index,explode=expload,autopct='%0.2f%%')
plt.show()

# %%
expload=[0,0,0.1]
color=['red','orange','purple']
plt.pie(x=df['class'].value_counts(),labels=df['class'].value_counts().index,explode=expload,autopct='%0.2f%%',colors=color)
plt.show()

# %%
color=['red','orange','purple']
plt.pie(x=df['class'].value_counts(),labels=df['class'].value_counts().index,autopct='%0.2f%%',colors=color)
circle=plt.Circle(xy=[0,0],radius=0.35,color='white')
plt.gca().add_artist(circle)
plt.show()

# %%
color=['red','orange','purple']
plt.figure(figsize=(8,8))
plt.pie(x=df['sex'].value_counts(),labels=df['sex'].value_counts().index,autopct='%0.2f%%',colors=color)
circle=plt.Circle(xy=[0,0],radius=0.35,color='white')
plt.gca().add_artist(circle)
plt.show()

# %%
plt.hist(df['fare'])
plt.show()

# %%
plt.hist(df['age']) # column distrubution 
plt.show()

# %%
plt.hist(df['alive'])
plt.show()

# %%
plt.boxplot(df['fare'])
plt.show()

# %%
df.boxplot()
plt.show()

# %%
for i in  df.select_dtypes(include=np.number).columns:
    sns.boxplot(df[i])
    plt.show()

# %%
# end of matplotlib
