# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.violinplot(x=df['sepal_length'],y=df['species'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='species'>

# %%
sns.violinplot(x=df['species'],y=df['sepal_length'])
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.swarmplot(x=df['petal_length'],y=df['species'])
# Out:
# <Axes: xlabel='petal_length', ylabel='species'>

# %%
sns.swarmplot(x=df['sepal_length'],y=df['species'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='species'>

# %%
sns.pairplot(df,hue='species') # hue for column

# %%
sns.pairplot(df)

# %%
sns.displot(df['sepal_length'],hist=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 sns.displot(df['sepal_length'],hist=False)
#
# File /opt/anaconda3/lib/python3.12/site-packages/seaborn/distributions.py:2193, in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2190 if p.univariate:
#    2192     _assign_default_kwargs(hist_kws, p.plot_univariate_histogram, histplot)
# -> 2193     p.plot_univariate_histogram(**hist_kws)
#    2195 else:
#    2197     _assign_default_kwargs(hist_kws, p.plot_bivariate_histogram, histplot)
#
# ...

# %%
sns.kdeplot(df['sepal_length'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
sns.countplot(df['petal_width'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.regplot(x=df['sepal_length'],y=df['sepal_width'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.pointplot(x=df['sepal_length'],y=df['species'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='species'>
