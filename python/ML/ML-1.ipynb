# %%
import seaborn as sns
import numpy as np 
import pandas as pd 
import scipy.stats as stats
import matplotlib.pyplot as plt 
from pylab import rcParams

import warnings
warnings.filterwarnings("ignore")

# %%
df_sales=pd.read_csv("/Users/avinashmagar/Documents/DataScience/python/Dataset/Marketing 2.0.csv")
df_sales.head()
# Out:
#      TV      Radio  Social Media       Sales
# 0  16.0   6.566231      2.907983   54.732757
# 1  13.0   9.237765      2.409567   46.677897
# 2  41.0  15.886446      2.913410  150.177829
# 3  83.0  30.020028      6.922304  298.246340
# 4  15.0   8.437408      1.405998   56.594181

# %%
df_sales.rename(columns={'Social Media':'social_media'},inplace=True)
df_sales
# Out:
#         TV      Radio  social_media       Sales
# 0     16.0   6.566231      2.907983   54.732757
# 1     13.0   9.237765      2.409567   46.677897
# 2     41.0  15.886446      2.913410  150.177829
# 3     83.0  30.020028      6.922304  298.246340
# 4     15.0   8.437408      1.405998   56.594181
# ...    ...        ...           ...         ...
# 4549  26.0   4.472360      0.717090   94.685866
# 4550  71.0  20.610685      6.545573  249.101915
# 4551  44.0  19.800072      5.096192  163.631457
# 4552  71.0  17.534640      1.940873  253.610411
# 4553  42.0  15.966688      5.046548  148.202414
#
# [4554 rows x 4 columns]

# %% [markdown]
# Relationship

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df_sales['TV'], y=df_sales['Sales'])
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df_sales['Radio'], y=df_sales['Sales'])
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df_sales['social_media'], y=df_sales['Sales'])
plt.show()

# %%
sns.heatmap(df_sales.corr(),annot=True)
plt.show()

# %%
import statsmodels.formula.api as sfa

model_tv=sfa.ols("Sales~TV",data=df_sales).fit()
model_tv.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.908
# Model:                            OLS   Adj. R-squared:                  0.908
# Method:                 Least Squares   F-statistic:                 4.485e+04
# Date:                Wed, 12 Feb 2025   Prob (F-statistic):               0.00
# Time:                        17:01:34   Log-Likelihood:                -21678.
# No. Observations:                4554   AIC:                         4.336e+04
# Df Residuals:                    4552   BIC:                         4.337e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     16.7037      0.930     17.969      0.000      14.881      18.526
# ...
