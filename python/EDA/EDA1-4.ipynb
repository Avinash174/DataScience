# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#standard scaler

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler_data=scaler.fit_transform(df[['sepal_width','sepal_length']])
scaler_data
# Out:
# array([[ 1.01900435, -0.90068117],
#        [-0.13197948, -1.14301691],
#        [ 0.32841405, -1.38535265],
#        [ 0.09821729, -1.50652052],
#        [ 1.24920112, -1.02184904],
#        [ 1.93979142, -0.53717756],
#        [ 0.78880759, -1.50652052],
#        [ 0.78880759, -1.02184904],
#        [-0.36217625, -1.74885626],
#        [ 0.09821729, -1.14301691],
#        [ 1.47939788, -0.53717756],
#        [ 0.78880759, -1.26418478],
#        [-0.13197948, -1.26418478],
#        [-0.13197948, -1.87002413],
#        [ 2.16998818, -0.05250608],
#        [ 3.09077525, -0.17367395],
#        [ 1.93979142, -0.53717756],
#        [ 1.01900435, -0.90068117],
#        [ 1.70959465, -0.17367395],
#        [ 1.70959465, -0.90068117],
#        [ 0.78880759, -0.53717756],
#        [ 1.47939788, -0.90068117],
#        [ 1.24920112, -1.50652052],
#        [ 0.55861082, -0.90068117],
#        [ 0.78880759, -1.26418478],
#        [-0.13197948, -1.02184904],
#        [ 0.78880759, -1.02184904],
# ...

# %%
# Min Max Scaler

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler_data=scaler.fit_transform(df[['sepal_width','sepal_length']])
scaler_data
# Out:
# array([[0.625     , 0.22222222],
#        [0.41666667, 0.16666667],
#        [0.5       , 0.11111111],
#        [0.45833333, 0.08333333],
#        [0.66666667, 0.19444444],
#        [0.79166667, 0.30555556],
#        [0.58333333, 0.08333333],
#        [0.58333333, 0.19444444],
#        [0.375     , 0.02777778],
#        [0.45833333, 0.16666667],
#        [0.70833333, 0.30555556],
#        [0.58333333, 0.13888889],
#        [0.41666667, 0.13888889],
#        [0.41666667, 0.        ],
#        [0.83333333, 0.41666667],
#        [1.        , 0.38888889],
#        [0.79166667, 0.30555556],
#        [0.625     , 0.22222222],
#        [0.75      , 0.38888889],
#        [0.75      , 0.22222222],
#        [0.58333333, 0.30555556],
#        [0.70833333, 0.22222222],
#        [0.66666667, 0.08333333],
#        [0.54166667, 0.22222222],
#        [0.58333333, 0.13888889],
#        [0.41666667, 0.19444444],
#        [0.58333333, 0.19444444],
#        [0.625     , 0.25      ],
# ...

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['sepal_width'], y=df['sepal_length'])  # Correct column names
plt.show()

# %%
np.log1p(df['sepal_length'])
# Out:
# 0      1.808289
# 1      1.774952
# 2      1.740466
# 3      1.722767
# 4      1.791759
#          ...
# 145    2.041220
# 146    1.987874
# 147    2.014903
# 148    1.974081
# 149    1.931521
# Name: sepal_length, Length: 150, dtype: float64

# %%
sns.histplot(df['sepal_length'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %% [markdown]
# Log Transform

# %%
col_log=df['col_log']=np.log(df['sepal_width'])
col_log
# Out:
# 0      1.252763
# 1      1.098612
# 2      1.163151
# 3      1.131402
# 4      1.280934
#          ...
# 145    1.098612
# 146    0.916291
# 147    1.098612
# 148    1.223775
# 149    1.098612
# Name: sepal_width, Length: 150, dtype: float64

# %% [markdown]
# Box-Cox Transformatio

# %%
from sklearn.preprocessing import PowerTransformer

pt = PowerTransformer(method='box-cox')
trans_col = pt.fit_transform(df[['sepal_length', 'sepal_width']])
trans_col
# Out:
# array([[-0.8947422 ,  1.02172936],
#        [-1.1851801 , -0.0819465 ],
#        [-1.48951683,  0.37432033],
#        [-1.64729682,  0.14883299],
#        [-1.03829865,  1.22864298],
#        [-0.48268062,  1.82557073],
#        [-1.64729682,  0.81052046],
#        [-1.03829865,  0.81052046],
#        [-1.97497756, -0.31832516],
#        [-1.1851801 ,  0.14883299],
#        [-0.48268062,  1.43146441],
#        [-1.33553382,  0.81052046],
#        [-1.33553382, -0.0819465 ],
#        [-2.14527615, -0.0819465 ],
#        [ 0.02770288,  2.01719347],
#        [-0.09602904,  2.75091815],
#        [-0.48268062,  1.82557073],
#        [-0.8947422 ,  1.02172936],
#        [-0.09602904,  1.63038201],
#        [-0.8947422 ,  1.63038201],
#        [-0.48268062,  0.81052046],
#        [-0.8947422 ,  1.43146441],
#        [-1.64729682,  1.22864298],
#        [-0.8947422 ,  0.59479673],
#        [-1.33553382,  0.81052046],
#        [-1.03829865, -0.0819465 ],
#        [-1.03829865,  0.81052046],
# ...

# %%
sns.histplot(df['col_log'])
# Out:
# <Axes: xlabel='col_log', ylabel='Count'>

# %% [markdown]
# Log1p Transformation

# %%
col_log1p=df['col_log1p']=np.log1p(df['sepal_width'])
col_log1p
# Out:
# 0      1.504077
# 1      1.386294
# 2      1.435085
# 3      1.410987
# 4      1.526056
#          ...
# 145    1.386294
# 146    1.252763
# 147    1.386294
# 148    1.481605
# 149    1.386294
# Name: sepal_width, Length: 150, dtype: float64

# %%
sns.histplot(df['col_log1p'])
# Out:
# <Axes: xlabel='col_log1p', ylabel='Count'>

# %% [markdown]
# yeo-johnson

# %%
yeo = PowerTransformer(method='yeo-johnson')
trans_col = yeo.fit_transform(df[['sepal_length']])
trans_col
# Out:
# array([[-0.89568956],
#        [-1.18517298],
#        [-1.48792061],
#        [-1.64460909],
#        [-1.03883758],
#        [-0.48420122],
#        [-1.64460909],
#        [-1.03883758],
#        [-1.9693691 ],
#        [-1.18517298],
#        [-0.48420122],
#        [-1.3348226 ],
#        [-1.3348226 ],
#        [-2.13777024],
#        [ 0.02642955],
#        [-0.09743879],
#        [-0.48420122],
#        [-0.89568956],
#        [-0.09743879],
#        [-0.89568956],
#        [-0.48420122],
#        [-0.89568956],
#        [-1.64460909],
#        [-0.89568956],
#        [-1.3348226 ],
#        [-1.03883758],
#        [-1.03883758],
#        [-0.75560892],
#        [-0.75560892],
#        [-1.48792061],
#        [-1.3348226 ],
#        [-0.48420122],
#        [-0.75560892],
#        [-0.35266426],
#        [-1.18517298],
#        [-1.03883758],
#        [-0.35266426],
#        [-1.18517298],
#        [-1.9693691 ],
#        [-0.89568956],
#        [-1.03883758],
# ...

# %%
sns.histplot(trans_col)
# Out:
# <Axes: ylabel='Count'>
