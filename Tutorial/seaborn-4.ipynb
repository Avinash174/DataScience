# %%
# part - 4

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as ptl

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
sns.barplot(x='class',y='fare',data=df)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.barplot(x='class',y='fare',data=df,hue='sex')
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.barplot(x='class',y='fare',data=df,hue='sex',palette='BuPu')
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.barplot(x='class',y='fare',data=df,hue='sex',palette='BuPu',orient='h')
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.barplot(x='class',y='fare',data=df,hue='sex',palette='BuPu',estimator=np.max)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.barplot(x='class',y='fare',data=df,hue='sex',palette='BuPu',ci=100,errcolor='red')
# Out:
# /var/folders/5p/b13xgh3d2mlbcnqmgjp7bysr0000gn/T/ipykernel_9272/3641247384.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 100)` for the same effect.
#
#   sns.barplot(x='class',y='fare',data=df,hue='sex',palette='BuPu',ci=100,errcolor='red')
# /var/folders/5p/b13xgh3d2mlbcnqmgjp7bysr0000gn/T/ipykernel_9272/3641247384.py:1: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'red'}` instead.
#
#   sns.barplot(x='class',y='fare',data=df,hue='sex',palette='BuPu',ci=100,errcolor='red')
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.barplot(x='class',y='fare',data=df,hue='sex',palette='BuPu',ci=100,errcolor='red',errwidth=10)
# Out:
# /var/folders/5p/b13xgh3d2mlbcnqmgjp7bysr0000gn/T/ipykernel_9272/320996758.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 100)` for the same effect.
#
#   sns.barplot(x='class',y='fare',data=df,hue='sex',palette='BuPu',ci=100,errcolor='red',errwidth=10)
# /var/folders/5p/b13xgh3d2mlbcnqmgjp7bysr0000gn/T/ipykernel_9272/320996758.py:1: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'red'}` instead.
#
#   sns.barplot(x='class',y='fare',data=df,hue='sex',palette='BuPu',ci=100,errcolor='red',errwidth=10)
# /var/folders/5p/b13xgh3d2mlbcnqmgjp7bysr0000gn/T/ipykernel_9272/320996758.py:1: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 10}` instead.
#
#   sns.barplot(x='class',y='fare',data=df,hue='sex',palette='BuPu',ci=100,errcolor='red',errwidth=10)
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.barplot(x='class',y='fare',data=df,hue='sex',palette='BuPu',ci=100,errcolor='red',errwidth=10,saturation=0.5)
# Out:
# /var/folders/5p/b13xgh3d2mlbcnqmgjp7bysr0000gn/T/ipykernel_9272/1704360179.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 100)` for the same effect.
#
#   sns.barplot(x='class',y='fare',data=df,hue='sex',palette='BuPu',ci=100,errcolor='red',errwidth=10,saturation=0.5)
# /var/folders/5p/b13xgh3d2mlbcnqmgjp7bysr0000gn/T/ipykernel_9272/1704360179.py:1: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'red'}` instead.
#
#   sns.barplot(x='class',y='fare',data=df,hue='sex',palette='BuPu',ci=100,errcolor='red',errwidth=10,saturation=0.5)
# /var/folders/5p/b13xgh3d2mlbcnqmgjp7bysr0000gn/T/ipykernel_9272/1704360179.py:1: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 10}` instead.
#
#   sns.barplot(x='class',y='fare',data=df,hue='sex',palette='BuPu',ci=100,errcolor='red',errwidth=10,saturation=0.5)
# ...
