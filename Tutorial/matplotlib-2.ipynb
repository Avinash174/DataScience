# %%
# part - 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
plt.style.use('dark_background')

# %%
roll_no=[1,2,3,4,5]
marks=[11,32,43,67,87]

# %%
plt.plot(roll_no,marks,'r-')
plt.show()

# %%
plt.plot(roll_no,marks,linestyle='-')

# %%
plt.plot(roll_no,marks,linestyle='--')

# %%
plt.plot(roll_no,marks,linestyle='--',color='#728569')

# %%
plt.plot(roll_no,marks,linestyle=':',color='orange')

# %%
plt.plot(roll_no,marks,linestyle='-.',color='red')

# %%
study_hours=[2,3,4,4,5,6,7,7,8,9,9,10,11,11,12]
marks=[6,10,15,20,34,44,55,60,70,80,90,99,100,55,54]

# %%
plt.figure(figsize=(8,8))
plt.xticks(np.arange(0,15,1))
plt.yticks(np.arange(0,100,5))

plt.plot(study_hours,marks,'r-')

plt.xlabel('study_hours')
plt.yticks('Marks')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axis.py:1769, in Axis.convert_units(self, x)
#    1768 try:
# -> 1769     ret = self.converter.convert(x, self.units, self)
#    1770 except Exception as e:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# ...

# %%
plt.figure(figsize=(8,8))
plt.xticks(np.arange(0,15,1))
plt.yticks(np.arange(0,100,5))

plt.plot(study_hours,marks,'r-')
plt.plot(study_hours,marks,'bo')

plt.xlabel('study_hours')
plt.yticks('Marks')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axis.py:1769, in Axis.convert_units(self, x)
#    1768 try:
# -> 1769     ret = self.converter.convert(x, self.units, self)
#    1770 except Exception as e:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# ...
