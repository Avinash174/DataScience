# %%
# part - 7

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np

# %%
image=img.imread('/Users/avinashmagar/Documents/Code/class/Tutorial/a.png')
plt.imshow(image)
plt.show()

# %%
plt.imshow(image,aspect=1)
plt.show()

# %%
plt.imshow(image,aspect=1)
plt.colorbar()
plt.show()

# %%
plt.imshow(image,aspect=1,cmap='grey')
plt.colorbar()
plt.show()

# %%
plt.imshow(image,aspect=1,cmap='YlOrRd_r')
plt.colorbar()
plt.show()
