# %%
# part - 6

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
study_hours=[2,2,3,4,5,5,6,7,7,8,8,9,9,1,4]
marks=[6,10,10,6,11,12,17,19,19,15,15,13,14,30,29]

# %%
plt.scatter(study_hours,marks)
plt.show()

# %%
plt.plot(study_hours,marks,'r-')
plt.show()

# %%
plt.hist(marks)
# Out:
# (array([2., 2., 3., 3., 1., 2., 0., 0., 0., 2.]),
#  array([ 6. ,  8.4, 10.8, 13.2, 15.6, 18. , 20.4, 22.8, 25.2, 27.6, 30. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(6,6))
plt.plot(study_hours,marks,'r-')
plt.plot(study_hours,marks,'bo')
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.subplot(2,2,1)
plt.plot(study_hours,marks,'r-')
plt.plot(study_hours,marks,'bo')

plt.subplot(2,2,4)
plt.plot(study_hours,marks,'r-')


plt.subplot(2,2,2) # row , col , index 
plt.scatter(study_hours,marks,)

plt.subplot(2,2,3)
plt.hist(marks)

# saving file 
plt.savefig('/Users/avinashmagar/Documents/Code/class/Tutorial/subplot1.png')
plt.show()
